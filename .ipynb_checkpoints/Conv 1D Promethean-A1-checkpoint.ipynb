# %%
import os
from os import listdir
from os.path import join
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
import statistics

import tensorflow as tf
from sklearn.model_selection import train_test_split
from tensorflow.keras.metrics import Recall, Precision, BinaryAccuracy
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler
import time

# %%
df1 = pd.read_csv("Healthy_z.csv")
df2 = pd.read_csv("A1_z.csv")

# %%
frames = [df1,df2]
final = pd.concat(frames)

# %%
final.head(10)
# Out:
#    Unnamed: 0       MAD    Median      Mean   Variance       Std   Kurtosis  \
# 0           0  4.693111  1.000400  0.353286  46.947659  6.851836   0.272563
# 1           1  0.011154  1.120448  1.120117   0.000206  0.014344   0.920398
# 2           2  0.188268  1.120936  1.108022   0.069256  0.263165  12.241497
# 3           3  0.239150  1.115568  1.119472   0.087780  0.296277  -0.350448
# 4           4  0.234109  1.114836  1.119892   0.084959  0.291476  -0.261811
# 5           5  0.226475  1.112640  1.120397   0.080455  0.283646  -0.149483
# 6           6  0.225494  1.110688  1.119855   0.079688  0.282290  -0.152900
# 7           7  0.226352  1.117764  1.120368   0.079164  0.281361  -0.209567
# 8           8  0.220387  1.111664  1.119311   0.075469  0.274717  -0.164408
# 9           9  0.201271  1.110688  1.119895   0.062804  0.250607  -0.218674
#
#        Skew  Crest Factor  Impulse Factor  Shape Factor  Anomaly
# 0 -0.197340      2.330628        3.324152      1.426290        0
# 1 -0.034632      1.071222        1.071310      1.000082        0
# 2 -1.767512      1.740156        1.775868      1.020522        0
# 3  0.102193      1.716407        1.775501      1.034429        0
# 4  0.158100      1.734902        1.792702      1.033316        0
# 5  0.201611      1.782271        1.838499      1.031549        0
# 6  0.205889      1.773452        1.828930      1.031282        0
# 7  0.141435      1.817394        1.873827      1.031052        0
# 8  0.212265      1.785122        1.838102      1.029678        0
# 9  0.165981      1.657153        1.698138      1.024732        0

# %%
y = final['Anomaly']
print(y)
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 645    1
# 646    1
# 647    1
# 648    1
# 649    1
# Name: Anomaly, Length: 1300, dtype: int64

# %%
df = final.drop(['Unnamed: 0', 'Anomaly'], axis=1)
df.head()
# Out:
#         MAD    Median      Mean   Variance       Std   Kurtosis      Skew  \
# 0  4.693111  1.000400  0.353286  46.947659  6.851836   0.272563 -0.197340
# 1  0.011154  1.120448  1.120117   0.000206  0.014344   0.920398 -0.034632
# 2  0.188268  1.120936  1.108022   0.069256  0.263165  12.241497 -1.767512
# 3  0.239150  1.115568  1.119472   0.087780  0.296277  -0.350448  0.102193
# 4  0.234109  1.114836  1.119892   0.084959  0.291476  -0.261811  0.158100
#
#    Crest Factor  Impulse Factor  Shape Factor
# 0      2.330628        3.324152      1.426290
# 1      1.071222        1.071310      1.000082
# 2      1.740156        1.775868      1.020522
# 3      1.716407        1.775501      1.034429
# 4      1.734902        1.792702      1.033316

# %%
scaler = StandardScaler()

scaler.fit(df)
data = scaler.transform(df)

# %%
print(data)
# Out:
# [[ 1.02069537e+01 -2.43828651e+00 -1.73145047e+01 ...  6.55929924e-02
#    3.53640012e-01  3.95663403e+00]
#  [-7.12503835e-01  6.06118737e-03  1.14627522e-01 ... -5.94557868e-01
#   -5.92031474e-01 -6.64063071e-01]
#  [-2.99430635e-01  1.59975601e-02 -1.60276591e-01 ... -2.43918516e-01
#   -2.96280449e-01 -4.42463056e-01]
#  ...
#  [-7.15660091e-01  5.57430511e-02  1.78265453e-01 ... -6.09612398e-01
#   -6.04098197e-01 -6.64306894e-01]
#  [-7.15559296e-01  5.57430511e-02  1.81269811e-01 ... -6.11499387e-01
#   -6.05608926e-01 -6.64294719e-01]
#  [-7.15819661e-01  7.56157965e-02  1.96037218e-01 ... -6.08398959e-01
#   -6.03126639e-01 -6.64312814e-01]]

# %%
x_train, x_test, y_train, y_test = train_test_split(data, y, test_size=0.3)
print(len(x_train), len(x_test), len(y_train), len(y_test))
# Out:
# 910 390 910 390

# %%
train_data = tf.convert_to_tensor(x_train)
val_data = tf.convert_to_tensor(x_test)
train_labels = tf.convert_to_tensor(y_train)
val_labels = tf.convert_to_tensor(y_test)
# Out:
# 2022-06-02 16:19:24.819607: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2022-06-02 16:19:24.819813: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2 AVX AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-06-02 16:19:24.820811: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.

# %%
print(train_data.shape)
print(val_data.shape)
print(train_labels.shape)
print(val_labels.shape)
# Out:
# (910, 10)
# (390, 10)
# (910,)
# (390,)

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.InputLayer(input_shape=(10)),
    tf.keras.layers.Reshape((10,1)),
    tf.keras.layers.Conv1D(32, kernel_size=(3), activation="relu", padding="valid"),
    tf.keras.layers.Conv1D(8, kernel_size=(3),activation="relu", padding="valid"),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(32, activation="relu"),
    tf.keras.layers.Dense(8, activation="relu"),
    tf.keras.layers.Dense(1, activation="sigmoid")
])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape_1 (Reshape)          (None, 10, 1)             0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 8, 32)             128
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 6, 8)              776
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 3, 8)              0
# _________________________________________________________________
# dropout (Dropout)            (None, 3, 8)              0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 24)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 32)                800
# _________________________________________________________________
# dense_4 (Dense)              (None, 8)                 264
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 9
# =================================================================
# Total params: 1,977
# Trainable params: 1,977
# Non-trainable params: 0
# _________________________________________________________________

# %%
lr = 1e-2
opt = tf.keras.optimizers.Adam(lr)
metrics = [BinaryAccuracy(), Recall(), Precision()]
model.compile(loss='binary_crossentropy', optimizer=opt, metrics=metrics)

# %%
callbacks = [
    #ModelCheckpoint("./Promethean_1D_H_A1.h5", verbose=1, save_best_model=True),
    #ReduceLROnPlateau(monitor="val_loss", patience=15, factor=0.1, verbose=1, min_lr=1e-6),
    #EarlyStopping(monitor="val_loss", patience=20, verbose=1),
]

# %%
start = time.time()
history = model.fit(train_data, train_labels, epochs=100, batch_size=128, validation_split=0.2)
print(time.time()-start)
# Out:
# Epoch 1/100
# 6/6 [==============================] - 1s 99ms/step - loss: 0.6696 - binary_accuracy: 0.4518 - recall_1: 0.8107 - precision_1: 0.4730 - val_loss: 0.6721 - val_binary_accuracy: 0.7912 - val_recall_1: 1.0000 - val_precision_1: 0.7164
# Epoch 2/100
# 6/6 [==============================] - 0s 42ms/step - loss: 0.6131 - binary_accuracy: 0.7465 - recall_1: 0.8842 - precision_1: 0.6946 - val_loss: 0.6004 - val_binary_accuracy: 0.8077 - val_recall_1: 1.0000 - val_precision_1: 0.7328
# Epoch 3/100
# 6/6 [==============================] - 0s 21ms/step - loss: 0.5561 - binary_accuracy: 0.7496 - recall_1: 0.6125 - precision_1: 0.8273 - val_loss: 0.5438 - val_binary_accuracy: 0.7088 - val_recall_1: 0.5417 - val_precision_1: 0.8525
# Epoch 4/100
# 6/6 [==============================] - 0s 31ms/step - loss: 0.5204 - binary_accuracy: 0.7778 - recall_1: 0.7444 - precision_1: 0.8133 - val_loss: 0.4947 - val_binary_accuracy: 0.6758 - val_recall_1: 0.3958 - val_precision_1: 0.9744
# Epoch 5/100
# 6/6 [==============================] - 0s 25ms/step - loss: 0.4867 - binary_accuracy: 0.7556 - recall_1: 0.5742 - precision_1: 0.8817 - val_loss: 0.4226 - val_binary_accuracy: 0.8022 - val_recall_1: 0.9479 - val_precision_1: 0.7459
# Epoch 6/100
# 6/6 [==============================] - 0s 24ms/step - loss: 0.4205 - binary_accuracy: 0.7713 - recall_1: 0.7372 - precision_1: 0.7815 - val_loss: 0.3743 - val_binary_accuracy: 0.8297 - val_recall_1: 1.0000 - val_precision_1: 0.7559
# Epoch 7/100
# 6/6 [==============================] - 0s 31ms/step - loss: 0.3878 - binary_accuracy: 0.8033 - recall_1: 0.8777 - precision_1: 0.7568 - val_loss: 0.3451 - val_binary_accuracy: 0.8297 - val_recall_1: 1.0000 - val_precision_1: 0.7559
# Epoch 8/100
# 6/6 [==============================] - 0s 43ms/step - loss: 0.3722 - binary_accuracy: 0.7866 - recall_1: 0.8690 - precision_1: 0.7537 - val_loss: 0.3589 - val_binary_accuracy: 0.7198 - val_recall_1: 0.5104 - val_precision_1: 0.9245
# Epoch 9/100
# 6/6 [==============================] - 0s 27ms/step - loss: 0.3396 - binary_accuracy: 0.7958 - recall_1: 0.8120 - precision_1: 0.7731 - val_loss: 0.3303 - val_binary_accuracy: 0.8297 - val_recall_1: 1.0000 - val_precision_1: 0.7559
# Epoch 10/100
# 6/6 [==============================] - 0s 18ms/step - loss: 0.3489 - binary_accuracy: 0.7910 - recall_1: 0.8866 - precision_1: 0.7490 - val_loss: 0.3378 - val_binary_accuracy: 0.8297 - val_recall_1: 1.0000 - val_precision_1: 0.7559
# Epoch 11/100
# 6/6 [==============================] - 0s 40ms/step - loss: 0.3139 - binary_accuracy: 0.8264 - recall_1: 0.9027 - precision_1: 0.7815 - val_loss: 0.3232 - val_binary_accuracy: 0.8297 - val_recall_1: 1.0000 - val_precision_1: 0.7559
# Epoch 12/100
# 6/6 [==============================] - 0s 20ms/step - loss: 0.3134 - binary_accuracy: 0.7963 - recall_1: 0.8817 - precision_1: 0.7487 - val_loss: 0.3269 - val_binary_accuracy: 0.8297 - val_recall_1: 1.0000 - val_precision_1: 0.7559
# Epoch 13/100
# 6/6 [==============================] - 0s 31ms/step - loss: 0.3128 - binary_accuracy: 0.8132 - recall_1: 0.9669 - precision_1: 0.7385 - val_loss: 0.3452 - val_binary_accuracy: 0.7033 - val_recall_1: 0.5208 - val_precision_1: 0.8621
# Epoch 14/100
# 6/6 [==============================] - 0s 25ms/step - loss: 0.2977 - binary_accuracy: 0.8213 - recall_1: 0.9004 - precision_1: 0.7683 - val_loss: 0.3214 - val_binary_accuracy: 0.8297 - val_recall_1: 1.0000 - val_precision_1: 0.7559
# Epoch 15/100
# 6/6 [==============================] - 0s 27ms/step - loss: 0.3214 - binary_accuracy: 0.8168 - recall_1: 0.9716 - precision_1: 0.7458 - val_loss: 0.3327 - val_binary_accuracy: 0.8297 - val_recall_1: 1.0000 - val_precision_1: 0.7559
# Epoch 16/100
# 6/6 [==============================] - 0s 26ms/step - loss: 0.3571 - binary_accuracy: 0.8022 - recall_1: 0.9195 - precision_1: 0.7383 - val_loss: 0.3206 - val_binary_accuracy: 0.8297 - val_recall_1: 1.0000 - val_precision_1: 0.7559
# Epoch 17/100
# 6/6 [==============================] - 0s 30ms/step - loss: 0.3289 - binary_accuracy: 0.8203 - recall_1: 0.9788 - precision_1: 0.7376 - val_loss: 0.3852 - val_binary_accuracy: 0.8187 - val_recall_1: 1.0000 - val_precision_1: 0.7442
# Epoch 18/100
# 6/6 [==============================] - 0s 19ms/step - loss: 0.3309 - binary_accuracy: 0.8206 - recall_1: 0.9533 - precision_1: 0.7484 - val_loss: 0.3531 - val_binary_accuracy: 0.8242 - val_recall_1: 1.0000 - val_precision_1: 0.7500
# Epoch 19/100
# 6/6 [==============================] - 0s 35ms/step - loss: 0.
# Epoch 71/100
# 6/6 [==============================] - 0s 52ms/step - loss: 0.2937 - binary_accuracy: 0.8374 - recall_1: 0.9688 - precision_1: 0.7722 - val_loss: 0.3105 - val_binary_accuracy: 0.8297 - val_recall_1: 1.0000 - val_precision_1: 0.7559
# Epoch 72/100
# 6/6 [==============================] - 0s 42ms/step - loss: 0.3137 - binary_accuracy: 0.8147 - recall_1: 0.9822 - precision_1: 0.7371 - val_loss: 0.3224 - val_binary_accuracy: 0.8297 - val_recall_1: 1.0000 - val_precision_1: 0.7559
# Epoch 73/100
# 6/6 [==============================] - 0s 40ms/step - loss: 0.2936 - binary_accuracy: 0.8295 - recall_1: 0.9931 - precision_1: 0.7512 - val_loss: 0.3106 - val_binary_accuracy: 0.8297 - val_recall_1: 1.0000 - val_precision_1: 0.7559
# Epoch 74/100
# 6/6 [==============================] - 0s 28ms/step - loss: 0.2914 - binary_accuracy: 0.8324 - recall_1: 1.0000 - precision_1: 0.7497 - val_loss: 0.3200 - val_binary_accuracy: 0.8297 - val_recall_1: 1.0000 - val_precision_1: 0.7559
# Epoch 75/100
# 6/6 [==============================] - 0s 43ms/step - loss: 0.3004 - binary_accuracy: 0.8247 - recall_1: 0.9920 - precision_1: 0.7427 - val_loss: 0.3136 - val_binary_accuracy: 0.8297 - val_recall_1: 1.0000 - val_precision_1: 0.7559
# Epoch 76/100
# 6/6 [==============================] - 0s 52ms/step - loss: 0.2945 - binary_accuracy: 0.8217 - recall_1: 0.9915 - precision_1: 0.7384 - val_loss: 0.3225 - val_binary_accuracy: 0.8077 - val_recall_1: 0.8125 - val_precision_1: 0.8211
# Epoch 77/100
# 6/6 [==============================] - 0s 60ms/step - loss: 0.2840 - binary_accuracy: 0.8118 - recall_1: 0.8196 - precision_1: 0.8014 - val_loss: 0.3120 - val_binary_accuracy: 0.8297 - val_recall_1: 1.0000 - val_precision_1: 0.7559
# Epoch 78/100
# 6/6 [==============================] - 0s 33ms/step - loss: 0.2779 - binary_accuracy: 0.8452 - recall_1: 0.9992 - precision_1: 0.7684 - val_loss: 0.3435 - val_binary_accuracy: 0.7692 - val_recall_1: 0.6458 - val_precision_1: 0.8857
# Epoch 79/100
# 6/6 [==============================] - 0s 52ms/step - loss: 0.2961 - binary_accuracy: 0.7983 - recall_1: 0.7145 - precision_1: 0.8284 - val_loss: 0.3379 - val_binary_accuracy: 0.8242 - val_recall_1: 1.0000 - val_precision_1: 0.7500
# Epoch 80/100
# 6/6 [==============================] - 0s 43ms/step - loss: 0.3208 - binary_accuracy: 0.8166 - recall_1: 0.9937 - precision_1: 0.7257 - val_loss: 0.3299 - val_binary_accuracy: 0.8242 - val_recall_1: 1.0000 - val_precision_1: 0.7500
# Epoch 81/100
# 6/6 [==============================] - 0s 51ms/step - loss: 0.2962 - binary_accuracy: 0.8283 - recall_1: 0.9974 - precision_1: 0.7407 - val_loss: 0.3263 - val_binary_accuracy: 0.8242 - val_recall_1: 1.0000 - val_precision_1: 0.7500
# Epoch 82/100
# 6/6 [==============================] - 0s 68ms/step - loss: 0.2895 - binary_accuracy: 0.8278 - recall_1: 0.9944 - precision_1: 0.7414 - val_loss: 0.3246 - val_binary_accuracy: 0.8242 - val_recall_1: 1.0000 - val_precision_1: 0.7500
# Epoch 83/100
# 6/6 [==============================] - 0s 41ms/step - loss: 0.3004 - binary_accuracy: 0.8285 - recall_1: 0.9948 - precision_1: 0.7492 - val_loss: 0.3262 - val_binary_accuracy: 0.8242 - val_recall_1: 1.0000 - val_precision_1: 0.7500
# Epoch 84/100
# 6/6 [==============================] - 0s 41ms/step - loss: 0.2954 - binary_accuracy: 0.8318 - recall_1: 0.9923 - precision_1: 0.7514 - val_loss: 0.3198 - val_binary_accuracy: 0.8297 - val_recall_1: 1.0000 - val_precision_1: 0.7559
# Epoch 85/100
# 6/6 [==============================] - 0s 24ms/step - loss: 0.3037 - binary_accuracy: 0.8331 - recall_1: 0.9900 - precision_1: 0.7570 - val_loss: 0.3209 - val_binary_accuracy: 0.8297 - val_recall_1: 1.0000 - val_precision_1: 0.7559
# Epoch 86/100
# 6/6 [==============================] - 0s 41ms/step - loss: 0.3025 - binary_accuracy: 0.8242 - recall_1: 0.9829 - precision_1: 0.7463 - val_loss: 0.3175 - val_binary_accuracy: 0.8297 - val_recall_1: 1.0000 - val_precision_1: 0.7559
# Epoch 87/100
# 6/6 [==============================] - 0s 33ms/step - loss: 0.2972 - binary_accuracy: 0.8173 - recall_1: 0.9988 - precision_1: 0.7264 - val_loss: 0.3149 - val_binary_accuracy: 0.8297 - val_recall_1: 1.0000 - val_precision_1: 0.7559
# Epoch 88/100
# 6/6 [==============================] - 0s 21ms/step - loss: 0.2799 - binary_accuracy: 0.8351 - recall_1: 0.9982 - precision_1: 0.7506 - val_loss: 0.3121 - val_binary_accuracy: 0.8297 - val_recall_1: 1.0000 - val_precision_1: 0.7559
# Epoch 89/100
# 6/6 [==============================] - 0s 31ms/step - loss: 0.2832 - binary_accuracy: 0.8380 - recall_1: 0.9917 - precision_1: 0.7594 - val_loss: 0.3115 - val_binary_accuracy: 0.8297 - val_recall_1: 1.0000 - val_precision_1: 0.7559
# Epoch 90/100
# 6/6 [==============================] - 0s 43ms/step - loss: 0.3094 - binary_accuracy: 0.7925 - recall_1: 0.8356 - precision_1: 0.7721 - val_loss: 0.3071 - val_binary_accuracy: 0.8297 - val_recall_1: 1.0000 - val_precision_1: 0.7559
# Epoch 91/100
# 6/6 [==============================] - 0s 37ms/step - loss: 0.3034 - binary_accuracy: 0.8297 - recall_1: 0.9970 - precision_1: 0.7516 - val_loss: 0.3188 - val_binary_accuracy: 0.8297 - val_recall_1: 1.0000 - val_precision_1: 0.7559
# Epoch 92/100
# 6/6 [==============================] - 0s 42ms/step - loss: 0.2872 - binary_accuracy: 0.8304 - recall_1: 0.9416 - precision_1: 0.7642 - val_loss: 0.3540 - val_binary_accuracy: 0.8242 - val_recall_1: 1.0000 - val_precision_1: 0.7500
# Epoch 93/100
# 6/6 [==============================] - 0s 21ms/step - loss: 0.2960 - binary_accuracy: 0.8223 - recall_1: 0.9848 - precision_1: 0.7358 - val_loss: 0.3462 - val_binary_accuracy: 0.8242 - val_recall_1: 1.0000 - val_precision_1: 0.7500
# Epoch 94/100
# 6/6 [==============================] - 0s 23ms/step - loss: 0.3000 - binary_accuracy: 0.8062 - recall_1: 0.9766 - precision_1: 0.7144 - val_loss: 0.3152 - val_binary_accuracy: 0.8242 - val_recall_1: 1.0000 - val_precision_1: 0.7500
# Epoch 95/100
# 6/6 [==============================] - 0s 34ms/step - loss: 0.2833 - binary_accuracy: 0.8209 - recall_1: 0.9622 - precision_1: 0.7506 - val_loss: 0.3084 - val_binary_accuracy: 0.8297 - val_recall_1: 1.0000 - val_precision_1: 0.7559
# Epoch 96/100
# 6/6 [==============================] - 0s 61ms/step - loss: 0.2932 - binary_accuracy: 0.8138 - recall_1: 0.9728 - precision_1: 0.7362 - val_loss: 0.3015 - val_binary_accuracy: 0.8297 - val_recall_1: 1.0000 - val_precision_1: 0.7559
# Epoch 97/100
# 6/6 [==============================] - 0s 26ms/step - loss: 0.2932 - binary_accuracy: 0.8194 - recall_1: 0.9709 - precision_1: 0.7470 - val_loss: 0.3047 - val_binary_accuracy: 0.8297 - val_recall_1: 1.0000 - val_precision_1: 0.7559
# Epoch 98/100
# 6/6 [==============================] - 0s 23ms/step - loss: 0.2779 - binary_accuracy: 0.8224 - recall_1: 0.9516 - precision_1: 0.7473 - val_loss: 0.3056 - val_binary_accuracy: 0.7967 - val_recall_1: 0.8333 - val_precision_1: 0.7921
# Epoch 99/100
# 6/6 [==============================] - 0s 22ms/step - loss: 0.2851 - binary_accuracy: 0.8153 - recall_1: 0.9156 - precision_1: 0.7619 - val_loss: 0.3142 - val_binary_accuracy: 0.8297 - val_recall_1: 1.0000 - val_precision_1: 0.7559
# Epoch 100/100
# 6/6 [==============================] - 0s 23ms/step - loss: 0.3006 - binary_accuracy: 0.8225 - recall_1: 0.9868 - precision_1: 0.7414 - val_loss: 0.3148 - val_binary_accuracy: 0.8297 - val_recall_1: 1.0000 - val_precision_1: 0.7559
# 22.403268814086914

# %%
# %cd ../Supervised Learning/Promethean-H and A1
model.save("./Promethean_1D_H-A1.h5")
# Out:
# Q:\TinyML\Supervised Learning\Promethean-H and A1

# %%
import seaborn as sns
from scipy.interpolate import make_interp_spline, BSpline

sns.set(style="whitegrid") # make background white colored 

tickfont = {'family' : 'Times', 'size'   : 12}
labelfont = {'family' : 'Times', 'size'   : 14}

fig = plt.figure(figsize = (8,5), dpi=200) # set figure size and resolution
ax = fig.add_subplot(111)

plt.plot(history.history['loss'], linestyle='-',color='darkorange', linewidth = 2.5, label = 'Training Loss')
plt.plot(history.history['val_loss'], linestyle='-',color='mediumblue', linewidth = 2.5, label = 'Validation Loss')
plt.title('Model Loss')

plt.xticks(**tickfont)
plt.yticks(**tickfont)

plt.grid(b=True, which='major', color='darkgray', linestyle='-',alpha=0.2)

plt.ylabel('Loss')
plt.xlabel('Epoch')

ax.spines['bottom'].set_color('k')
ax.spines['top'].set_color('k') 
ax.spines['right'].set_color('k')
ax.spines['left'].set_color('k')
plt.legend(prop={'size': 14}, loc = 'upper right')
plt.show()
# Out:
# findfont: Font family ['Times'] not found. Falling back to DejaVu Sans.

# %%
sns.set(style="whitegrid") # make background white colored 

tickfont = {'family' : 'Times', 'size'   : 12}
labelfont = {'family' : 'Times', 'size'   : 14}

fig = plt.figure(figsize = (8,5), dpi=200) # set figure size and resolution
ax = fig.add_subplot(111)

plt.plot(history.history['binary_accuracy'], linestyle='-',color='darkorange', linewidth = 2.5, label = 'Training Accuracy')
plt.plot(history.history['val_binary_accuracy'], linestyle='-',color='mediumblue', linewidth = 2.5, label = 'Validation Accuracy')
plt.title('Model Accuracy')

plt.xticks(**tickfont)
plt.yticks(**tickfont)

plt.grid(b=True, which='major', color='darkgray', linestyle='-',alpha=0.2)

plt.ylabel('Accuracy')
plt.xlabel('Epoch')

ax.spines['bottom'].set_color('k')
ax.spines['top'].set_color('k') 
ax.spines['right'].set_color('k')
ax.spines['left'].set_color('k')
plt.legend(prop={'size': 14}, loc = 'lower right')
plt.show()

# %%
sns.set(style="whitegrid") # make background white colored 

tickfont = {'family' : 'Times', 'size'   : 12}
labelfont = {'family' : 'Times', 'size'   : 14}

fig = plt.figure(figsize = (8,5), dpi=200) # set figure size and resolution
ax = fig.add_subplot(111)

# plt.plot(history.history['precision'], linestyle='-',color='darkorange', linewidth = 2.5, label = 'Training Precision')
# plt.plot(history.history['val_precision'], linestyle='-',color='mediumblue', linewidth = 2.5, label = 'Validation Precision')
plt.plot(history.history['recall'], linestyle='-',color='darkorange', linewidth = 2.5, label = 'Training Recall')
plt.plot(history.history['val_recall'], linestyle='-',color='mediumblue', linewidth = 2.5, label = 'Validation Recall')
plt.title('Recall')

plt.xticks(**tickfont)
plt.yticks(**tickfont)

plt.grid(b=True, which='major', color='darkgray', linestyle='-',alpha=0.2)

plt.ylabel('Recall')
plt.xlabel('Epoch')

ax.spines['bottom'].set_color('k')
ax.spines['top'].set_color('k') 
ax.spines['right'].set_color('k')
ax.spines['left'].set_color('k')
plt.legend(prop={'size': 14}, loc = 'lower right')
plt.show()

# %%
sns.set(style="whitegrid") # make background white colored 

tickfont = {'family' : 'Times', 'size'   : 12}
labelfont = {'family' : 'Times', 'size'   : 14}

fig = plt.figure(figsize = (8,5), dpi=200) # set figure size and resolution
ax = fig.add_subplot(111)

plt.plot(history.history['precision'], linestyle='-',color='darkorange', linewidth = 2.5, label = 'Training Precision')
plt.plot(history.history['val_precision'], linestyle='-',color='mediumblue', linewidth = 2.5, label = 'Validation Precision')
# plt.plot(history.history['recall'], linestyle='-',color='darkorange', linewidth = 2.5, label = 'Training Recall')
# plt.plot(history.history['val_recall'], linestyle='-',color='mediumblue', linewidth = 2.5, label = 'Validation Recall')
plt.title('Precision')

plt.xticks(**tickfont)
plt.yticks(**tickfont)

plt.grid(b=True, which='major', color='darkgray', linestyle='-',alpha=0.2)

plt.ylabel('Parameters')
plt.xlabel('Epoch')

ax.spines['bottom'].set_color('k')
ax.spines['top'].set_color('k') 
ax.spines['right'].set_color('k')
ax.spines['left'].set_color('k')
plt.legend(prop={'size': 14}, loc = 'lower right')
plt.show()

# %%
#load the model

import keras
import keras.utils
from keras import utils as np_utils
reconstructed_model = keras.models.load_model("Promethean_1D_H-A1.h5")

#use model for test data
val_labels = np.array(val_labels).reshape([val_labels.shape[0],1])
predictions = reconstructed_model.predict(val_data)

print(predictions.shape)
print(val_labels.shape)

for i in range(len(val_labels)):
    if predictions[i] >= 0.5:
        predictions[i] = 1
    else:
            predictions[i] =0
    print("Test_images=%s, Predicted=%s" % (val_labels[i],(predictions[i])))
# Out:
# (390, 1)
# (390, 1)
# Test_images=[1], Predicted=[1.]
# Test_images=[0], Predicted=[0.]
# Test_images=[0], Predicted=[0.]
# Test_images=[1], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[0], Predicted=[0.]
# Test_images=[0], Predicted=[0.]
# Test_images=[0], Predicted=[0.]
# Test_images=[0], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[0], Predicted=[0.]
# Test_images=[0], Predicted=[0.]
# Test_images=[1], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[0], Predicted=[0.]
# Test_images=[1], Predicted=[1.]
# Test_images=[0], Predicted=[0.]
# Test_images=[0], Predicted=[0.]
# Test_images=[0], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[0], Predicted=[1.]
# Test_images=[0], Predicted=[0.]
# Test_images=[1], Predicted=[1.]
# Test_images=[0], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[0], Predicted=[0.]
# Test_images=[0], Predicted=[0.]
# Test_images=[0], Predicted=[0.]
# Test_images=[0], Predicted=[0.]
# Test_images=[0], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[0], Predicted=[0.]
# Test_images=[1], Predicted=[1.]
# Test_images=[0], Predicted=[1.]
# Test_images=[0], Predicted=[0.]
# Test_images=[1], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[0], Predicted=[0.]
# Test_images=[0], Predicted=[0.]
# Test_images=[1], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[0], Predicted=[0.]
# Test_images=[0], Predicted=[0.]
# Test_images=[1], Predicted=[1.]
# Test_images=[0], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[0], Predicted=[0.]
# Test_images=[0], Predicted=[0.]
# Test_images=[0], Predicted=[0.]
# Test_images=[1], Predicted=[1.]
# Test_images=[0], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[0], Predicted=[1.]
# Test_images=[0], Predicted=[0.]
# Test_images=[0], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[0], Predicted=[1.]
# Test_images=[0], Predicted=[0.]
# Test_images=[0], Predicted=[1.]
# Test_images=[0], Predicted=[0.]
# Test_images=[0], Predicted=[0.]
# Test_images=[0], Predicted=[0.]
# Test_images=[0], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[0], Predicted=[0.]
# Test_images=[0], Predicted=[0.]
# Test_images=[0], Predicted=[0.]
# Test_images=[0], Predicted=[1.]
# Test_images=[0], Predicted=[1.]
# Test_images=[0], Predicted=[0.]
# Test_images=[0], Predicted=[0.]
# Test_images=[1], Predicted=[1.]
# Test_images=[0], Predicted=[0.]
# Test_images=[0], Predicted=[0.]
# Test_images=[1], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[0], Predicted=[0.]
# Test_images=[0], Predicted=[0.]
# Test_images=[1], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[0], Predicted=[0.]
# Test_images=[0], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[0], Predicted=[0.]
# Test_images=[0], Predicted=[1.]
# Test_images=[0], Predicted=[0.]
# Test_images=[0], Predicted=[0.]
# Test_images=[0], Predicted=[1.]
# Test_images=[0], Predicted=[0.]
# Test_images=[1], Predicted=[1.]
# Test_images=[0], Predicted=[0.]
# Test_images=[0], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[0], Predicted=[0.]
# Test_images=[0], Predicted=[0.]
# Test_images=[1], Predicted=[1.]
# Test_images=[0], Predicted=[0.]
# Test_images=[1], Predicted=[1.]
# Test_images=[0], Predicted=[0.]
# Test_images=[1], Predicted=[1.]
# Test_images=[0], Predicted=[0.]
# Test_images=[1], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[0], Predicted=[0.]
# Test_images=[0], Predicted=[0.]
# Test_images=[1], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[0], Predicted=[0.]
# Test_images=[0], Predicted=[1.]
# Test_images=[0], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[0], Predicted=[1.]
# Test_images=[0], Predicted=[1.]
# Test_images=[0], Predicted=[0.]
# Test_images=[0], Predicted=[0.]
# Test_images=[0], Predicted=[1.]
# Test_images=[0], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[0], Predicted=[0.]
# Test_images=[0], Predicted=[0.]
# Test_images=[0], Predicted=[0.]
# Test_images=[0], Predicted=[0.]
# Test_images=[0], Predicted=[0.]
# Test_images=[1], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[0], Predicted=[0.]
# Test_images=[0], Predicted=[0.]
# Test_images=[1], Predicted=[1.]
# Test_images=[0], Predicted=[0.]
# Test_images=[1], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[0], Predicted=[0.]
# Test_images=[0], Predicted=[0.]
# Test_images=[0], Predicted=[0.]
# Test_images=[1], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[0], Predicted=[0.]
# Test_images=[1], Predicted=[1.]
# Test_images=[0], Predicted=[1.]
# Test_images=[0], Predicted=[0.]
# Test_images=[1], Predicted=[1.]
# Test_images=[1], Predicted=[0.]
# Test_images=[1], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[0], Predicted=[0.]
# Test_images=[0], Predicted=[0.]
# Test_images=[0], Predicted=[0.]
# Test_images=[1], Predicted=[1.]
# Test_images=[0], Predicted=[1.]
# Test_images=[0], Predicted=[0.]
# Test_images=[1], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[0], Predicted=[0.]
# Test_images=[1], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[0], Predicted=[0.]
# Test_images=[0], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[0], Predicted=[0.]
# Test_images=[1], Predicted=[1.]
# Test_images=[0], Predicted=[1.]
# Test_images=[0], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[0], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[0], Predicted=[0.]
# Test_images=[0], Predicted=[0.]
# Test_images=[1], Predicted=[1.]
# Test_images=[0], Predicted=[0.]
# Test_images=[0], Predicted=[1.]
# Test_images=[0], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[0], Predicted=[0.]
# Test_images=[1], Predicted=[1.]
# Test_images=[0], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[0], Predicted=[0.]
# Test_images=[1], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[0], Predicted=[0.]
# Test_images=[1], Predicted=[1.]
# Test_images=[0], Predicted=[1.]
# Test_images=[0], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[0], Predicted=[0.]
# Test_images=[1], Predicted=[1.]
# Test_images=[0], Predicted=[0.]
# Test_images=[1], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[0], Predicted=[1.]
# Test_images=[0], Predicted=[0.]
# Test_images=[1], Predicted=[1.]
# Test_images=[0], Predicted=[0.]
# Test_images=[0], Predicted=[0.]
# Test_images=[1], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[0], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[0], Predicted=[0.]
# Test_images=[1], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[0], Predicted=[0.]
# Test_images=[1], Predicted=[1.]
# Test_images=[0], Predicted=[0.]
# Test_images=[1], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[0], Predicted=[1.]
# Test_images=[0], Predicted=[0.]
# Test_images=[1], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[0], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[0], Predicted=[0.]
# Test_images=[0], Predicted=[0.]
# Test_images=[1], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[0], Predicted=[1.]
# Test_images=[0], Predicted=[0.]
# Test_images=[0], Predicted=[1.]
# Test_images=[0], Predicted=[1.]
# Test_images=[0], Predicted=[0.]
# Test_images=[1], Predicted=[1.]
# Test_images=[0], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[0], Predicted=[0.]
# Test_images=[0], Predicted=[0.]
# Test_images=[1], Predicted=[1.]
# Test_images=[0], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[0], Predicted=[0.]
# Test_images=[0], Predicted=[0.]
# Test_images=[1], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[0], Predicted=[0.]
# Test_images=[0], Predicted=[0.]
# Test_images=[1], Predicted=[1.]
# Test_images=[0], Predicted=[0.]
# Test_images=[1], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[0], Predicted=[1.]
# Test_images=[0], Predicted=[0.]
# Test_images=[1], Predicted=[1.]
# Test_images=[0], Predicted=[0.]
# Test_images=[0], Predicted=[0.]
# Test_images=[1], Predicted=[1.]
# Test_images=[0], Predicted=[1.]
# Test_images=[0], Predicted=[0.]
# Test_images=[1], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[0], Predicted=[0.]
# Test_images=[0], Predicted=[1.]
# Test_images=[0], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[0], Predicted=[0.]
# Test_images=[0], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[0], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[0], Predicted=[0.]
# Test_images=[0], Predicted=[0.]
# Test_images=[1], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[0], Predicted=[0.]
# Test_images=[1], Predicted=[1.]
# Test_images=[0], Predicted=[0.]
# Test_images=[0], Predicted=[1.]
# Test_images=[0], Predicted=[0.]
# Test_images=[1], Predicted=[1.]
# Test_images=[0], Predicted=[0.]
# Test_images=[0], Predicted=[0.]
# Test_images=[0], Predicted=[1.]
# Test_images=[0], Predicted=[0.]
# Test_images=[0], Predicted=[0.]
# Test_images=[1], Predicted=[1.]
# Test_images=[0], Predicted=[0.]
# Test_images=[1], Predicted=[1.]
# Test_images=[0], Predicted=[0.]
# Test_images=[0], Predicted=[1.]
# Test_images=[0], Predicted=[0.]
# Test_images=[0], Predicted=[0.]
# Test_images=[0], Predicted=[0.]
# Test_images=[0], Predicted=[1.]
# Test_images=[0], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[0], Predicted=[0.]
# Test_images=[1], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[0], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[0], Predicted=[0.]
# Test_images=[0], Predicted=[0.]
# Test_images=[1], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[0], Predicted=[0.]
# Test_images=[1], Predicted=[1.]
# Test_images=[0], Predicted=[0.]
# Test_images=[1], Predicted=[1.]
# Test_images=[0], Predicted=[0.]
# Test_images=[1], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[0], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[0], Predicted=[0.]
# Test_images=[0], Predicted=[1.]
# Test_images=[0], Predicted=[0.]
# Test_images=[0], Predicted=[0.]
# Test_images=[0], Predicted=[1.]
# Test_images=[0], Predicted=[0.]
# Test_images=[0], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[0], Predicted=[0.]
# Test_images=[1], Predicted=[1.]
# Test_images=[0], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[0], Predicted=[1.]
# Test_images=[0], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[1], Predicted=[1.]
# Test_images=[0], Predicted=[0.]
# Test_images=[1], Predicted=[1.]

# %%
conf_matrix = confusion_matrix(val_labels, predictions)

# %%
sns.set(style="whitegrid") # make background white colored

tickfont = {'family' : 'Times', 'size'   : 14}
labelfont = {'family' : 'Times', 'size'   : 16}

fig = plt.figure(figsize=(8,5), dpi=200)
ax = fig.add_subplot(111)

df_cm = pd.DataFrame(conf_matrix, range(2), range(2))

sns.heatmap(df_cm, cmap="Blues", annot=True, fmt='.0f', annot_kws={"size":16})

plt.show()

# %%
accuracy_score(val_labels, predictions)
# Out:
# 0.8333333333333334

# %%
from sklearn.metrics import f1_score
f1_score(val_labels, predictions)
# Out:
# 0.8558758314855875
